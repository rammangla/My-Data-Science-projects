# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns',100)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data='Worksheet in Analytics_Case_Resolvr2020.xlsx'
resolvr_df=pd.read_excel(io=data,sheet_name='Case Study 2020')
resolvr_df.head()
# Out:
#    Customer ID  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         5047    Male  disloyal Customer   25  Business travel  Business
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 4       119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                    3.0                                4.0
# 1              235                    3.0                                2.0
# 2             1142                    2.0                                2.0
# 3              562                    2.0                                5.0
# 4              214                    3.0                                3.0
#
# ...

# %%
resolvr_df.shape
# Out:
# (129880, 24)

# %%
resolvr_df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
resolvr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Customer ID                        129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Inflight wifi service              129876 non-null  float64
#  8   Departure/Arrival time convenient  129876 non-null  float64
#  9   Ease of Online booking             129877 non-null  float64
#  10  Gate location                      129872 non-null  float64
# ...

# %%
resolvr_df.describe(include='all').T
# Out:
#                                     count unique              top    freq  \
# Customer ID                        129880    NaN              NaN     NaN
# Gender                             129880      2           Female   65899
# Customer Type                      129880      2   Loyal Customer  106100
# Age                                129880    NaN              NaN     NaN
# Type of Travel                     129880      2  Business travel   89693
# Class                              129880      3         Business   62160
# Flight Distance                    129880    NaN              NaN     NaN
# Inflight wifi service              129876    NaN              NaN     NaN
# Departure/Arrival time convenient  129876    NaN              NaN     NaN
# Ease of Online booking             129877    NaN              NaN     NaN
# Gate location                      129872    NaN              NaN     NaN
# Food and drink                     129875    NaN              NaN     NaN
# ...

# %% [markdown]
# Customer ID is of no use in our analysis. We can remove it

# %%
del resolvr_df['Customer ID']

# %% [markdown]
# ##Dealing with missing values

# %%
resolvr_df.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  4
# Departure/Arrival time convenient      4
# Ease of Online booking                 3
# Gate location                          8
# Food and drink                         5
# Online boarding                        6
# Seat comfort                           1
# Inflight entertainment                 4
# On-board service                       3
# Leg room service                       2
# Baggage handling                       2
# Checkin service                        3
# Inflight service                       1
# Cleanliness                            2
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# ...

# %% [markdown]
# Missing values will be imputed with values based on the analysis done in seperate file .

# %%
#new_df[new_df['Inflight wifi service'].isnull()]
#customers 3 out of 4 customers are unsatisfied .therefore fill nan with low rating .(considering other factors also)
resolvr_df['Inflight wifi service'].fillna(2.0, inplace = True)

# %%
#new_df[new_df['Departure/Arrival time convenient'].isnull()]
# all customers are unsatisfied.therefore fill nan with low rating 
resolvr_df['Departure/Arrival time convenient'].fillna(2.0, inplace = True)

# %%
#new_df[new_df['Ease of Online booking'].isnull()]
# gives rating 1 because Gender(male,female),customertype these have major unsatisfaction of ease of online booking
resolvr_df['Ease of Online booking'].fillna(1.0, inplace = True)

# %%
#new_df[new_df['Gate location'].isnull()]
# Gate location is not the major cause of unsatisfaction.So using mode value
resolvr_df['Gate location'].fillna(3.0, inplace = True)

# %%
# food and drink is not a mojor criteria for unsatisfaction
resolvr_df['Food and drink'].fillna(4.0, inplace = True)

# %%
#new_df[new_df['Online boarding'].isnull()]
resolvr_df['Online boarding'].fillna(3.0, inplace = True)

# %%
resolvr_df['Seat comfort'].fillna(4.0, inplace = True)
resolvr_df['Inflight entertainment'].fillna(4.0, inplace = True)  
resolvr_df['On-board service'].fillna(4.0, inplace = True)
resolvr_df['Leg room service'].fillna(4.0, inplace = True)
resolvr_df['Baggage handling'].fillna(4.0, inplace = True)
resolvr_df['Checkin service'].fillna(4.0, inplace = True)
resolvr_df['Inflight service'].fillna(4.0, inplace = True)
resolvr_df['Cleanliness'].fillna(4.0, inplace = True)
resolvr_df['Arrival Delay in Minutes'].fillna(0.0, inplace = True)

# %% [markdown]
# ## Univariate EDA categorical variable

# %%
resolvr_df['Gender'].value_counts(dropna=False)
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64

# %%
resolvr_df['Customer Type'].value_counts()
# Out:
# Loyal Customer       106100
# disloyal Customer     23780
# Name: Customer Type, dtype: int64

# %%
resolvr_df['Type of Travel'].value_counts()
# Out:
# Business travel    89693
# Personal Travel    40187
# Name: Type of Travel, dtype: int64

# %%
resolvr_df['Class'].value_counts()
# Out:
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: Class, dtype: int64

# %%
resolvr_df['Gender'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
resolvr_df['Customer Type'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
resolvr_df['Type of Travel'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
resolvr_df['Class'].value_counts().plot.pie(autopct='%1.1f%%')

# %% [markdown]
# 1. No of Males and females are almost equal
# 2. Loyal Customers are much more than disloyal customers
# 3. People travelling for buisness purpose are most
# 4. Most preferred classes are buisness and Eco

# %% [markdown]
# ### Univariate analysis of rating parameters

# %%
resolvr_df.shape
# Out:
# (129880, 23)

# %%
resolvr_df['Inflight wifi service'].value_counts()
# Out:
# 2.0    32322
# 3.0    32185
# 4.0    24775
# 1.0    22327
# 5.0    14355
# 0.0     3916
# Name: Inflight wifi service, dtype: int64

# %%
resolvr_df['Departure/Arrival time convenient'].value_counts()
# Out:
# 4.0    31879
# 5.0    27998
# 3.0    22377
# 2.0    21536
# 1.0    19409
# 0.0     6681
# Name: Departure/Arrival time convenient, dtype: int64

# %%
resolvr_df['Ease of Online booking'].value_counts()
# Out:
# 3.0    30393
# 2.0    30050
# 4.0    24443
# 1.0    21888
# 5.0    17424
# 0.0     5682
# Name: Ease of Online booking, dtype: int64

# %%
#There is only 1 passenger with gate location rating of 0.It's better to remove it
resolvr_df=resolvr_df[resolvr_df['Gate location']!=0]

# %%
resolvr_df['Gate location'].value_counts()
# Out:
# 3.0    35722
# 4.0    30463
# 2.0    24296
# 1.0    21989
# 5.0    17409
# Name: Gate location, dtype: int64

# %%
#There are only 132 customers with food rating of 0.This implies food rating is not that much bad.These customers are acting like outliers
#Better is to remove these customers
resolvr_df=resolvr_df[resolvr_df['Food and drink']!=0]
resolvr_df['Food and drink'].value_counts()
# Out:
# 4.0    30567
# 5.0    27956
# 3.0    27793
# 2.0    27382
# 1.0    16049
# Name: Food and drink, dtype: int64

# %%
resolvr_df['Online boarding'].value_counts(dropna='False')
# Out:
# 4.0    38448
# 3.0    27087
# 5.0    25995
# 2.0    21911
# 1.0    13226
# 0.0     3080
# Name: Online boarding, dtype: int64

# %%
resolvr_df['Seat comfort'].value_counts(dropna='False')
# Out:
# 4.0    39732
# 5.0    33136
# 3.0    23294
# 2.0    18500
# 1.0    15084
# 0.0        1
# Name: Seat comfort, dtype: int64

# %%
resolvr_df['Inflight entertainment'].value_counts()
# Out:
# 4.0    36760
# 5.0    31518
# 3.0    23853
# 2.0    21955
# 1.0    15656
# 0.0        5
# Name: Inflight entertainment, dtype: int64

# %%
resolvr_df['On-board service'].value_counts(dropna=False)
# Out:
# 4.0    38681
# 5.0    29462
# 3.0    28514
# 2.0    18313
# 1.0    14772
# 0.0        5
# Name: On-board service, dtype: int64

# %%
sample_1=resolvr_df[resolvr_df['Leg room service']==0]
sample_2=resolvr_df[resolvr_df['Leg room service']!=0]

# %%
#It's better to include people with 0 leg room service to 1 rating leg room service

# %%
resolvr_df.loc[resolvr_df['Leg room service']==0,['Leg room service']]=1

# %%
resolvr_df['Leg room service'].value_counts()
# Out:
# 4.0    35834
# 5.0    30874
# 3.0    25027
# 2.0    24530
# 1.0    13482
# Name: Leg room service, dtype: int64

# %%
resolvr_df['Baggage handling'].value_counts(dropna='False')
# Out:
# 4.0    46714
# 5.0    33845
# 3.0    25816
# 2.0    14351
# 1.0     9021
# Name: Baggage handling, dtype: int64

# %%
#There is only 1 customer with checkin service rating as 0
resolvr_df=resolvr_df[resolvr_df['Checkin service']!=0]
resolvr_df['Checkin service'].value_counts()
# Out:
# 4.0    36314
# 3.0    35417
# 5.0    25861
# 1.0    16082
# 2.0    16072
# Name: Checkin service, dtype: int64

# %%
resolvr_df['Inflight service'].value_counts()
# Out:
# 4.0    47281
# 5.0    34047
# 3.0    25275
# 2.0    14293
# 1.0     8845
# 0.0        5
# Name: Inflight service, dtype: int64

# %%
resolvr_df=resolvr_df[resolvr_df['Inflight service']!=0]

# %%
resolvr_df['Cleanliness'].value_counts()
# Out:
# 4.0    33949
# 3.0    30606
# 5.0    28395
# 2.0    20087
# 1.0    16704
# Name: Cleanliness, dtype: int64

# %%
resolvr_df['satisfaction'].value_counts()
# Out:
# 0    73369
# 1    56372
# Name: satisfaction, dtype: int64

# %% [markdown]
# ## Univariate analysis of continuous variable

# %%
resolvr_df.shape
# Out:
# (129741, 23)

# %%
plt.style.use('seaborn-whitegrid')

# %%
resolvr_df['Age'].describe()
# Out:
# count    129741.000000
# mean         39.434435
# std          15.117276
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
lower_bound=27-1.5*(51-27)
high_bound=51+1.5*(51-27)
print(lower_bound)
print(high_bound)
# Out:
# -9.0
# 87.0

# %%
plt.figure(figsize=(10,5))
plt.subplots_adjust(wspace=.1)
plt.subplot(1,2,1)
sns.distplot(a=resolvr_df['Age'],bins=10,norm_hist=True,label='Age histogram')
count,bin_edges=np.histogram(resolvr_df['Age'],bins=10)
plt.xticks(ticks=bin_edges)
plt.legend()
plt.subplot(1,2,2)
sns.boxplot(x=resolvr_df['Age'],color='green',orient='vertical',whis=2)
plt.yticks(ticks=[7,27,40,51,85])
# Out:
# ([<matplotlib.axis.YTick at 0x7f889e620080>,
# ...
#  <a list of 5 Text major ticklabel objects>)

# %%
print(count)
print(bin_edges)
# Out:
# [ 6447 12406 21956 19473 21973 21492 17095  7172  1496   231]
# [ 7.  14.8 22.6 30.4 38.2 46.  53.8 61.6 69.4 77.2 85. ]

# %%
resolvr_df['Flight Distance'].describe()
# Out:
# count    129741.000000
# mean       1190.244772
# std         997.276080
# min          31.000000
# 25%         414.000000
# 50%         844.000000
# 75%        1744.000000
# max        4983.000000
# Name: Flight Distance, dtype: float64

# %%
lower_bound=414-1.5*(1744-414)
upper_bound=1744+1.5*(1744-414)
print(lower_bound)
print(upper_bound)
# Out:
# -1581.0
# 3739.0

# %%
sns.distplot(resolvr_df['Flight Distance'],bins=10)

# %%
sample=resolvr_df['Flight Distance']

# %%
from scipy.stats import boxcox
sample=pd.Series(boxcox(resolvr_df['Flight Distance'])[0])

# %%
sample.describe()
# Out:
# count    129741.000000
# mean          9.972661
# std           1.894544
# min           4.164840
# 25%           8.519281
# 50%           9.947629
# 75%          11.521700
# max          14.030637
# dtype: float64

# %%
sns.distplot(resolvr_df['Flight Distance'],bins=10)

# %%
resolvr_df['Flight Distance'].skew()
# Out:
# 1.1081880156384152

# %%
resolvr_df['Departure Delay in Minutes'].describe()
# Out:
# count    129741.000000
# mean         14.598677
# std          37.677865
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          12.000000
# max        1592.000000
# Name: Departure Delay in Minutes, dtype: float64

# %%
count,bin_edges=np.histogram(resolvr_df['Departure Delay in Minutes'],bins=120)
fig=plt.figure()
ax=plt.axes()
sns.distplot(resolvr_df['Departure Delay in Minutes'],bins=100)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
print(count[:10])
print(bin_edges[:10])
# Out:
# [98811 10693  5970  3955  2410  1757  1298  1014   761   556]
# [  0.          13.26666667  26.53333333  39.8         53.06666667
#   66.33333333  79.6         92.86666667 106.13333333 119.4       ]

# %%
#Departure time can be categorized into 3 parts i.e. 0 to 14,14 to 100 and 100 and above

# %%
def cut(x):
  if x<=14:
    return 0
  elif 14<x<100:
    return 1
  else:
    return 2  
resolvr_df['Departure Delay in Minutes']=resolvr_df['Departure Delay in Minutes'].apply(cut)

# %%
resolvr_df['Departure Delay in Minutes'].value_counts()
# Out:
# 0    99990
# 1    25453
# 2     4298
# Name: Departure Delay in Minutes, dtype: int64

# %%
resolvr_df['Arrival Delay in Minutes'].describe()
# Out:
# count    129741.000000
# mean         14.928827
# std          38.022113
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay in Minutes, dtype: float64

# %%
fig=plt.figure()
ax=plt.axes()
sns.distplot(resolvr_df['Arrival Delay in Minutes'],bins=150)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
#The same bins we have created in case of departure delay can be made in case of arrival delay as well

# %%
resolvr_df['Arrival Delay in Minutes']=resolvr_df['Arrival Delay in Minutes'].apply(cut)

# %%
resolvr_df['Arrival Delay in Minutes'].value_counts(dropna=False)
# Out:
# 0    99221
# 1    26112
# 2     4408
# Name: Arrival Delay in Minutes, dtype: int64

# %%
resolvr_df.shape
# Out:
# (129741, 23)

# %%
resolvr_df[['Arrival Delay in Minutes','Departure Delay in Minutes','satisfaction']].corr()
# Out:
#                             Arrival Delay in Minutes  \
# Arrival Delay in Minutes                    1.000000
# Departure Delay in Minutes                  0.802841
# satisfaction                               -0.079732
#
#                             Departure Delay in Minutes  satisfaction
# Arrival Delay in Minutes                      0.802841     -0.079732
# Departure Delay in Minutes                    1.000000     -0.067269
# satisfaction                                 -0.067269      1.000000

# %%
#There is strong correlation between these two columns. This means one column is unnecessary
resolvr_df.drop(axis=1,columns='Departure Delay in Minutes',inplace=True)

# %%
resolvr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129741 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129741 non-null  object
#  1   Customer Type                      129741 non-null  object
#  2   Age                                129741 non-null  int64
#  3   Type of Travel                     129741 non-null  object
#  4   Class                              129741 non-null  object
#  5   Flight Distance                    129741 non-null  int64
#  6   Inflight wifi service              129741 non-null  float64
#  7   Departure/Arrival time convenient  129741 non-null  float64
#  8   Ease of Online booking             129741 non-null  float64
#  9   Gate location                      129741 non-null  float64
#  10  Food and drink                     129741 non-null  float64
# ...

# %% [markdown]
# ## Multivariate EDA

# %%
sns.catplot(x='Gender',y='satisfaction',data=resolvr_df,kind='bar')

# %% [markdown]
# Gender as a single variable doesn't seem to have much impact on satisfaction.

# %%
plt.figure(figsize=(10,6))
plt.subplots_adjust(wspace=.2)
plt.subplot(1,2,1)
sns.barplot(x='Customer Type',y='satisfaction',data=resolvr_df)
plt.subplot(1,2,2)
sns.barplot(x='Customer Type',y='satisfaction',data=resolvr_df,hue='Gender')

# %% [markdown]
# Loyal Customers are definitely more satisfied as compared to disloyal(irregular customers).

# %%
sns.barplot(x='Type of Travel',y='satisfaction',data=resolvr_df)

# %%
sns.catplot(x='Type of Travel',y='satisfaction',hue='Gender',col='Customer Type',data=resolvr_df,kind='bar')

# %% [markdown]
# Gender still doesn't have any impact on satisfaction.
# 1. **Among loyal customers**,different between two purposes of travel is high
# 2. **Among disloyal customers** difference is low.
# People travelling for personal purpose are still less satisfied than people travelling for business purpose

# %%
sns.catplot(x='Class',y='satisfaction',data=resolvr_df,kind='bar')

# %%
plt.subplots_adjust(wspace=.5)
sns.catplot(x='Class',y='satisfaction',hue='Customer Type',col='Type of Travel',data=resolvr_df,kind='bar')

# %%
sns.countplot(x='Class',hue='Type of Travel',data=resolvr_df)

# %% [markdown]
# * Gender doesn't have any impact
# * Those travelling for personal purpose mostly prefer Eco or Eco Plus and only few prefer Business Class
# * Those travelling for business purpose mostly prefer business or Eco
# * Most satisfaction is offered by business class and least by Eco
# * When loyal people are travelling for business purpose, they have more satisfaction irrespective of whichever class they're travelling in
# * *For improving the satisfaction of personal purpose travelling customers company need to work on improving it's Eco class*

# %%
plt.figure(figsize=(10,12))
plt.subplots_adjust(hspace=.2)
plt.subplot(2,1,1)
sns.lineplot(x='Age',y='satisfaction',data=resolvr_df,hue='Gender')
plt.subplot(2,1,2)
sns.lineplot(x='Age',y='satisfaction',data=resolvr_df)

# %% [markdown]
# Gender doesn't seem to have any influence on Age vs satisfaction.
# But Females of old age are seem to be more satisfied
# * Most satisfied people are those in age range of 40-60
# *There is almost increasing trend for persons of age 0-40.
# * Dissatisfied customers range from a) below 20 b) b/w 60 and 72 c) 77 and above

# %%
fig=plt.figure(figsize=(10,6))
ax=plt.axes()
sns.distplot(a=resolvr_df.loc[resolvr_df['satisfaction']==0,['Flight Distance']],bins=100,hist=False,label='0',ax=ax)
sns.distplot(a=resolvr_df.loc[resolvr_df['satisfaction']==1,['Flight Distance']],bins=100,color='yellow',hist=False,label='1',ax=ax)
ax.legend(title='satisfaction')
ax.set_xlabel('Flight Distance')
ax.set_ylabel('Satisfaction')
ax.set_xticks(ticks=np.arange(-500,5000,500))

# %% [markdown]
# It can be seen that satisfaction level is higher than unsatisfied level for distance greater than approx. 1300 km. As the distance is increasing the satisfaction level is increasing

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.barplot(x=resolvr_df['Class'],y=resolvr_df['Flight Distance'])
plt.subplot(1,2,2)
sns.barplot(x='Class',y='Flight Distance',hue='Type of Travel',data=resolvr_df)

# %% [markdown]
# * Earlier we have found that business travel purpose customers are more satisfied in every class
# * Further we have found business class is most satisfied.
# * It can be seen from here that distance greater than 1300 is travelled for Business purpose that too in business class.
# That's why distance greater than 1300km are satisfiable.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Inflight wifi service',y='satisfaction',data=resolvr_df)
resolvr_df[['Inflight wifi service','Class']].groupby(by='Class').mean()
# Out:
#           Inflight wifi service
# Class
# Business               2.777030
# Eco                    2.675819
# Eco Plus               2.761210

# %% [markdown]
# * This should not be confused that 0 rating has high satisfaction. This is due to other factors.
# * This is also showing that Inflight wifi service doesn't have much influence on satisfaction.
# *All the 3 classes have almost same wifi service

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Departure/Arrival time convenient',y='satisfaction',data=resolvr_df)
resolvr_df[['Departure/Arrival time convenient','Class']].groupby(by='Class').mean()
# Out:
#           Departure/Arrival time convenient
# Class
# Business                           2.908655
# Eco                                3.192836
# Eco Plus                           3.211311

# %% [markdown]
# * This is also not showing expected trend.
# * This factor is not that much important
# * Business classes fails most on this parameter showing people travelling from business class pays more importance to this.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Ease of Online booking',y='satisfaction',data=resolvr_df)
resolvr_df[['Ease of Online booking','Class']].groupby(by='Class').mean()
# Out:
#           Ease of Online booking
# Class
# Business                2.916962
# Eco                     2.605794
# Eco Plus                2.666099

# %% [markdown]
# * This unusual behaviour is due to other factors.
# * Business Class has more ease of online booking as compared to others

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Gate location',y='satisfaction',data=resolvr_df)
resolvr_df[['Gate location','Class']].groupby(by='Class').mean()
# Out:
#           Gate location
# Class
# Business       2.985044
# Eco            2.969727
# Eco Plus       2.969006

# %% [markdown]
# * Gate location factor is indifferent to class
# * Unusual behaviour is due to other factors

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Food and drink',y='satisfaction',data=resolvr_df)
resolvr_df[['Food and drink','Class']].groupby(by='Class').mean()
# Out:
#           Food and drink
# Class
# Business        3.332072
# Eco             3.090477
# Eco Plus        3.118010

# %% [markdown]
# * It seems to be a relevant factor since satisfaction level is increasing with it's rating.
# * Eco class has slightly need to improve it's food

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Online boarding',y='satisfaction',data=resolvr_df)
resolvr_df[['Online boarding','Class']].groupby(by='Class').mean()
# Out:
#           Online boarding
# Class
# Business         3.719541
# Eco              2.814702
# Eco Plus         2.885930

# %% [markdown]
# * It's also an important factor according to it's trend
# * The unexpected behaviour of rating 0 is due to other factors
# * Eco and Eco Plus class has lots of work to do on online boarding

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Seat comfort',y='satisfaction',data=resolvr_df)
resolvr_df[['Seat comfort','Class']].groupby(by='Class').mean()
# Out:
#           Seat comfort
# Class
# Business      3.764521
# Eco           3.141974
# Eco Plus      3.168176

# %% [markdown]
# * Seat comfort is clearly an important factor
# * Improving seat comfort in Eco and Eco Plus can improve satisfaction level to high extent

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Inflight entertainment',y='satisfaction',data=resolvr_df)
resolvr_df[['Inflight entertainment','Class']].groupby(by='Class').mean()
# Out:
#           Inflight entertainment
# Class
# Business                3.639964
# Eco                     3.096555
# Eco Plus                3.122803

# %% [markdown]
# * Inflight entertainment is a major parameter for deciding satisfaction level
# * Providing more inflight entertainment particularly in eco and eco plus can improve satisfaction level

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='On-board service',y='satisfaction',data=resolvr_df)
resolvr_df[['On-board service','Class']].groupby(by='Class').mean()
# Out:
#           On-board service
# Class
# Business          3.683190
# Eco               3.119600
# Eco Plus          3.036745

# %% [markdown]
# * Have drastic impact on satisfaction level
# * Eco and Eco plus need to improve it to high extent

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Leg room service',y='satisfaction',data=resolvr_df)
resolvr_df[['Leg room service','Class']].groupby(by='Class').mean()
# Out:
#           Leg room service
# Class
# Business          3.648818
# Eco               3.089567
# Eco Plus          3.061774

# %% [markdown]
# * This is also an important deciding variable of satisfaction level

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Baggage handling',y='satisfaction',data=resolvr_df)
resolvr_df[['Baggage handling','Class']].groupby(by='Class').mean()
# Out:
#           Baggage handling
# Class
# Business          3.845016
# Eco               3.450340
# Eco Plus          3.351475

# %% [markdown]
# * Also a good deciding parameter
# *Eco Plus need to work on this

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Checkin service',y='satisfaction',data=resolvr_df)
resolvr_df[['Checkin service','Class']].groupby(by='Class').mean()
# Out:
#           Checkin service
# Class
# Business         3.521685
# Eco              3.124631
# Eco Plus         3.014698

# %% [markdown]
# * Also an important deciding parameter
# * Eco Plus need to work on this parameter

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Inflight service',y='satisfaction',data=resolvr_df)
resolvr_df[['Inflight service','Class']].groupby(by='Class').mean()
# Out:
#           Inflight service
# Class
# Business          3.847012
# Eco               3.466790
# Eco Plus          3.382895

# %% [markdown]
# * Also a good deciding parameter
# * Eco Plus need to work on this

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Cleanliness',y='satisfaction',data=resolvr_df)
resolvr_df[['Cleanliness','Class']].groupby(by='Class').mean()
# Out:
#           Cleanliness
# Class
# Business     3.482822
# Eco          3.105158
# Eco Plus     3.120247

# %% [markdown]
# * An absolutely necessary parameter
# *Eco and Eco Plus need to work on it

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Arrival Delay in Minutes',y='satisfaction',data=resolvr_df)
resolvr_df[['Arrival Delay in Minutes','Type of Travel']].groupby(by='Type of Travel').mean()
# Out:
#                  Arrival Delay in Minutes
# Type of Travel
# Business travel                  0.272133
# Personal Travel                  0.262692

# %% [markdown]
# * For both types of travel purpose arrival delay matters the same.
# * Lesser the arrival delay more will be the satisfaction

# %% [markdown]
# ### Insights from other file

# %% [markdown]
# * Percentage of satisfied and unsatisfied customers are 43.4 and 53.6% respectively. This clearly shows there is lot of scope for improvement.
# * Inflight wifi service, Ease of online booking, Online boarding, Inflight entertainment, Cleanliness, food and drink, gate location are the factors having overall rating <3.

# %% [markdown]
# ## Data Preprocessing

# %%
resolvr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129741 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129741 non-null  object
#  1   Customer Type                      129741 non-null  object
#  2   Age                                129741 non-null  int64
#  3   Type of Travel                     129741 non-null  object
#  4   Class                              129741 non-null  object
#  5   Flight Distance                    129741 non-null  int64
#  6   Inflight wifi service              129741 non-null  float64
#  7   Departure/Arrival time convenient  129741 non-null  float64
#  8   Ease of Online booking             129741 non-null  float64
#  9   Gate location                      129741 non-null  float64
#  10  Food and drink                     129741 non-null  float64
# ...

# %%
sample=pd.get_dummies(data=resolvr_df['Gender'],drop_first=True)
resolvr_df=pd.concat([sample,resolvr_df],axis=1)

# %%
resolvr_df.drop(axis=1,columns=['Gender'],inplace=True)

# %%
sample=pd.get_dummies(data=resolvr_df['Customer Type'],drop_first=True)

# %%
resolvr_df=pd.concat([sample,resolvr_df],axis=1)
resolvr_df.drop(axis=1,columns=['Customer Type'],inplace=True)

# %%
resolvr_df['Age']=pd.cut(resolvr_df['Age'],bins=[0,20,40,60,72,100],labels=['age_0','age_1','age_2','age_3','age_4'])

# %%
resolvr_df['Age']=resolvr_df['Age'].astype('object')

# %%
sample=pd.get_dummies(resolvr_df['Age'],drop_first=True)

# %%
resolvr_df=pd.concat([sample,resolvr_df],axis=1)
del resolvr_df['Age']

# %%
sample=pd.get_dummies(resolvr_df['Type of Travel'],drop_first=True)
resolvr_df=pd.concat([sample,resolvr_df],axis=1)

# %%
del resolvr_df['Type of Travel']

# %%
def ordin(x):
  if x=='Eco':
    return 0
  elif x=='Eco Plus':
    return 1
  else:
    return 2

# %%
resolvr_df['Class']=resolvr_df['Class'].apply(ordin)

# %%
cor=resolvr_df[['Male','Flight Distance','Class','Personal Travel','satisfaction']].corr()
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d27f6daa_f90f_11ea_8d1c_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d27f6daa_f90f_11ea_8d1c_0242ac1c0002row0_col1 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_d27f6daa_f90f_11ea_8d1c_0242ac1c0002row0_col2 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_d27f6daa_f90f_11ea_8d1c_0242ac1c0002row0_col3 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_d27f6daa_f90f_11ea_8d1c_0242ac1c0002row0_col4 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_d27f6daa_f90f_11ea_8d1c_0242ac1c0002row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d27f6daa_f90f_11ea_8d1c_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...

# %%
#As the inference drawn flight distance has strong correlation with class
#To avoid collinearity, it is better to del this variable
del resolvr_df['Flight Distance']

# %%
corr=resolvr_df.corr()
plt.figure(figsize=(10,8))
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d2c93f70_f90f_11ea_8d1c_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d2c93f70_f90f_11ea_8d1c_0242ac1c0002row0_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_d2c93f70_f90f_11ea_8d1c_0242ac1c0002row0_col2 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_d2c93f70_f90f_11ea_8d1c_0242ac1c0002row0_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_d2c93f70_f90f_11ea_8d1c_0242ac1c0002row0_col4 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_d2c93f70_f90f_11ea_8d1c_0242ac1c0002row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d2c93f70_f90f_11ea_8d1c_0242ac1c0002row0_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
# ...

# %%
resolvr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129741 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Personal Travel                    129741 non-null  uint8
#  1   age_1                              129741 non-null  uint8
#  2   age_2                              129741 non-null  uint8
#  3   age_3                              129741 non-null  uint8
#  4   age_4                              129741 non-null  uint8
#  5   disloyal Customer                  129741 non-null  uint8
#  6   Male                               129741 non-null  uint8
#  7   Class                              129741 non-null  int64
#  8   Inflight wifi service              129741 non-null  float64
#  9   Departure/Arrival time convenient  129741 non-null  float64
#  10  Ease of Online booking             129741 non-null  float64
# ...

# %%
X=resolvr_df.iloc[:,:-1].values
y=resolvr_df.iloc[:,-1].values

# %%
X.shape
# Out:
# (129741, 23)

# %%
y.shape
# Out:
# (129741,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.3,random_state=0)

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# ## Model Building

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,f1_score
from sklearn.model_selection import cross_val_score,GridSearchCV,RandomizedSearchCV

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(random_state=0)

# %%
parameters=[{'C':[1,.1,.5,.8,2,5],'solver':['lbfgs','liblinear','saga']}]

# %%
grid_model=GridSearchCV(lr,param_grid=parameters,scoring='accuracy',cv=5)

# %%
grid_model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-1ac66cd2843d> in <module>()
# ----> 1 grid_model.fit(X_train,y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# ...

# %%
print(grid_model.best_params_)
print(grid_model.best_score_)

# %%
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('f1-score:',f1_score(y_test,y_pred))

# %%
cm=confusion_matrix(y_test,y_pred)
print(cm)

# %% [markdown]
# ### Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GNB_classifier=GaussianNB()

# %%
GNB_classifier.fit(X_train,y_train)
y_pred=GNB_classifier.predict(X_test)
print('Accuracy:',accuracy_score(y_test,y_pred))
print('f1-score:',f1_score(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
print(cm)

# %% [markdown]
# ### KNN classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN_classifier=KNeighborsClassifier()

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC=DecisionTreeClassifier()
DTC.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred=DTC.predict(X_test)
print('Accuracy:',accuracy_score(y_test,y_pred))
print('f1-score:',f1_score(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# Accuracy: 0.9432212316625131
# f1-score: 0.9348774163130598
# [[20850  1189]
#  [ 1021 15863]]

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC=RandomForestClassifier()
RFC.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=RFC.predict(X_test)
print('Accuracy:',accuracy_score(y_test,y_pred))
print('f1-score:',f1_score(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# Accuracy: 0.9598437941576959
# f1-score: 0.9530221514231614
# [[21506   533]
#  [ 1030 15854]]

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GBC=GradientBoostingClassifier()
GBC.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
y_pred=GBC.predict(X_test)
print('Accuracy:',accuracy_score(y_test,y_pred))
print('f1-score:',f1_score(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# Accuracy: 0.9419366441435655
# f1-score: 0.9323434319243203
# [[21091   948]
#  [ 1312 15572]]

# %% [markdown]
# ## XG Boost Classifier

# %%
from xgboost import XGBClassifier

# %%
XGB=XGBClassifier()

# %%
XGB.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred=XGB.predict(X_test)
print('Accuracy:',accuracy_score(y_test,y_pred))
print('f1-score:',f1_score(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# Accuracy: 0.9408062071268916
# f1-score: 0.9309145427286357
# [[21096   943]
#  [ 1361 15523]]
